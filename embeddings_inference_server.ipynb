# %%
# !pip install -r requirements.txt

# %%
import os

os.environ["NGROK_AUTH_TOKEN"] = "YOUR_NGROK_TOKEN"
os.environ["MODEL_DIR"] = "mlsa-iai-msu-lab/sci-rus-tiny" # any HF embeddings model
print(os.environ["NGROK_AUTH_TOKEN"])

# %%
# !python run_server.py
